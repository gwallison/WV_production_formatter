# %% [markdown]
# # West Virginia Production dataset - WVGES version

# %%
# python/pandas preamble
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
import zipfile, os

# different sets contain input files that are formatted similarly
#set1_dir = './sources/set1/'
#set2_dir = './sources/set2/'
#set3_dir = './sources/set3/'
#set4_dir = './sources/set4/'
datadir = './sources/'
outdir = './out/'

# %% [markdown]
# # Production data from WVGES

# %% [markdown]
# See website <http://www.wvgs.wvnet.edu/www/datastat/devshales.htm>  for lots of resources.  This includes
# an excel sheet with lots of metadata on each unconventional well. We use that here to filter out conventional wells and for lat/lon, as well as monthly production.
#
# **Note that the original file is in read-only lock.  You must make an explicit copy within Excel to successfully read in these data.**

# %%
klst = ['API','YEAR','G_JAN','G_FEB','G_MAR','G_APR','G_MAY','G_JUN','G_JUL','G_AUG','G_OCT','G_NOV','G_DEC',
        'O_JAN','O_FEB','O_MAR','O_APR','O_MAY','O_JUN','O_JUL','O_AUG','O_OCT','O_NOV','O_DEC',
        'NGL_JAN','NGL_FEB','NGL_MAR','NGL_APR','NGL_MAY','NGL_JUN','NGL_JUL','NGL_AUG','NGL_OCT','NGL_NOV','NGL_DEC',]
prod = pd.read_excel(datadir+'Copy of WVGES Marcellus Wells.xls',sheet_name='WV Marcellus Prod',
                     usecols=klst, skiprows=1)

# %% [markdown]
# The dataset has some records back to 1979 for working wells that are fracked in the early 2000's.  Presumably, the back records are included to demonstrate the difference between conventional and non-conventional.   I am leaving off years before 2002 (the earliest spud date) to keep the dataset from being swamped with empty cells.

# %%
prod = prod[prod.YEAR>2001]
prod.head()
# Out:
#           API  YEAR   G_JAN   G_FEB   G_MAR   G_APR   G_MAY   G_JUN   G_JUL  \
# 0  4700102885  2008     0.0     0.0   956.0  1082.0  1397.0  1158.0  1179.0
# 1  4700102885  2009   758.0  1104.0   774.0   881.0   437.0   711.0   408.0
# 2  4700102885  2010  1797.0  1385.0  1270.0  1024.0   899.0  1170.0   952.0
# 3  4700102885  2011   748.0   717.0   617.0   590.0   590.0   689.0   636.0
# 4  4700102885  2012   589.0   636.0   719.0   602.0   677.0   433.0   583.0
#
#     G_AUG  ...  NGL_FEB  NGL_MAR  NGL_APR  NGL_MAY  NGL_JUN  NGL_JUL  NGL_AUG  \
# 0  1013.0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1   346.0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2   747.0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3   512.0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4   259.0  ...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    NGL_OCT  NGL_NOV  NGL_DEC
# 0      NaN      NaN      NaN
# 1      NaN      NaN      NaN
# 2      NaN      NaN      NaN
# 3      NaN      NaN      NaN
# 4      NaN      NaN      NaN
#
# [5 rows x 35 columns]

# %%
prod.groupby("YEAR").count()
# Out:
#        API  G_JAN  G_FEB  G_MAR  G_APR  G_MAY  G_JUN  G_JUL  G_AUG  G_OCT  \
# YEAR
# 2002    53     53     53     53     53     53     53     53     53     53
# 2003    55     55     55     55     55     55     55     55     55     55
# 2004    58     58     58     58     58     58     58     58     58     58
# 2005   126    126    126    126    126    126    126    126    126    126
# 2006   380    380    380    380    380    380    380    380    380    380
# 2007   734    734    734    734    734    734    734    734    734    734
# 2008  1218   1218   1218   1218   1218   1218   1218   1218   1218   1218
# 2009  1378   1378   1378   1378   1378   1378   1378   1378   1378   1378
# 2010  1563   1563   1563   1563   1563   1563   1563   1563   1563   1563
# 2011  1802   1802   1802   1802   1802   1802   1802   1802   1802   1802
# 2012  2087   2087   2087   2087   2087   2087   2087   2087   2087   2087
# 2013  2476   2476   2476   2476   2476   2476   2476   2476   2476   2476
# 2014  2890   2890   2890   2890   2890   2890   2890   2890   2890   2890
# 2015  3062   3062   3062   3062   3062   3062   3062   3062   3062   3062
# 2016  3296   3296   3296   3296   3296   3296   3296   3296   3296   3296
# 2017  3589   3589   3589   3589   3589   3589   3589   3589   3589   3589
# 2018  1375   1375   1375   1375   1375   1375   1375   1375   1375   1375
#
#       ...  NGL_FEB  NGL_MAR  NGL_APR  NGL_MAY  NGL_JUN  NGL_JUL  NGL_AUG  \
# YEAR  ...
# 2002  ...        0        0        0        0        0        0        0
# 2003  ...        0        0        0        0        0        0        0
# 2004  ...        0        0        0        0        0        0        0
# 2005  ...        0        0        0        0        0        0        0
# 2006  ...        0        0        0        0        0        0        0
# 2007  ...        0        0        0        0        0        0        0
# 2008  ...        0        0        0        0        0        0        0
# 2009  ...        0        0        0        0        0        0        0
# 2010  ...        0        0        0        0        0        0        0
# 2011  ...        0        0        0        0        0        0        0
# 2012  ...        0        0        0        0        0        0        0
# 2013  ...     2476     2476     2476     2476     2476     2476     2476
# 2014  ...     2890     2890     2890     2890     2890     2890     2890
# 2015  ...     3062     3062     3062     3062     3062     3062     3062
# 2016  ...     1016     1016     1016     1016     1016     1016     1016
# 2017  ...      242      240      238      264      254      272      345
# 2018  ...     1375     1375     1375     1375     1375     1375     1375
#
#       NGL_OCT  NGL_NOV  NGL_DEC
# YEAR
# 2002        0        0        0
# 2003        0        0        0
# 2004        0        0        0
# 2005        0        0        0
# 2006        0        0        0
# 2007        0        0        0
# 2008        0        0        0
# 2009        0        0        0
# 2010        0        0        0
# 2011        0        0        0
# 2012        0        0        0
# 2013     2476     2476     2476
# 2014     2890     2890     2890
# 2015     3062     3062     3062
# 2016     1016     1016     1016
# 2017      368      375      379
# 2018     1375     1375     1375
#
# [17 rows x 34 columns]

# %%
xlate = {'JAN':'01', 'FEB':'02', 'MAR':'03', 'APR':'04', 'MAY':'05', 'JUN':'06',
         'JUL':'07', 'AUG':'08', 'SEP':'09', 'OCT':'10', 'NOV':'11', 'DEC':'12'}

def getColName(row):
    yr = str(row.YEAR)
    mo = xlate[row.variable[-3:]]
    return f'Y{yr}M{mo}'
    

mprod = prod.melt(id_vars=['API','YEAR'])
mprod = mprod.groupby(['API','YEAR','variable'],as_index=False)['value'].max()

mprod['typ'] = np.where(mprod.variable.str[0]=='G','GAS',np.nan)
mprod.typ = np.where(mprod.variable.str[0]=='O','OIL',mprod.typ)
mprod.typ = np.where(mprod.variable.str[0]=='N','NGL',mprod.typ)
mprod['yrmo'] = mprod.apply(lambda x: getColName(x),axis=1)
mprod.tail()
# Out:
#                API  YEAR variable  value  typ      yrmo
# 855487  4710903065  2017    O_JUN    NaN  OIL  Y2017M06
# 855488  4710903065  2017    O_MAR    NaN  OIL  Y2017M03
# 855489  4710903065  2017    O_MAY    NaN  OIL  Y2017M05
# 855490  4710903065  2017    O_NOV    NaN  OIL  Y2017M11
# 855491  4710903065  2017    O_OCT    NaN  OIL  Y2017M10

# %%
mprod.to_pickle(outdir+'ver2.pkl')

# %% [markdown]
# # Metadata from WVGES

# %%
klst = ['API Number','County Name','Operator at Completion',
        'Surface Loc Longitude','Surface Loc Latitude','Spud Date']
meta = pd.read_excel(datadir+'Copy of WVGES Marcellus Wells.xlsx',sheet_name='Completed Marcellus Wells',
                     usecols=klst, skiprows=1)
meta.columns = ['API','CountyName','OperatorName',
        'Surf_Long','Surf_Lat','Spud Date']

meta.head()
# Out:
#           API CountyName                             OperatorName  Surf_Long  \
# 0  4700102885    Barbour            Seneca-Upshur Petroleum Corp. -79.973910
# 1  4700102981    Barbour  EXCO - North Coast Energy Eastern, Inc. -80.108525
# 2  4700102985    Barbour        Dominion Exploration & Production -80.020647
# 3  4700102994    Barbour              Petroleum Development Corp. -80.016268
# 4  4700103013    Barbour              Petroleum Development Corp. -80.170851
#
#     Surf_Lat  Spud Date
# 0  39.008158  8/13/2007
# 1  39.045433  8/30/2008
# 2  39.204180  7/30/2009
# 3  39.185397  1/17/2009
# 4  39.232015  7/15/2009

# %%
print(f'Len meta: {len(meta)}, unique API: {len(meta.API.unique())}')
# Out:
# Len meta: 3718, unique API: 3703

# %%
#  Need to take most recent meta record:
meta = meta.groupby('API',as_index=False).last()

# %%
print(f'Len meta: {len(meta)}, unique API: {len(meta.API.unique())}')
# Out:
# Len meta: 3703, unique API: 3703

# %% [markdown]
# # Make the output files

# %%
def makeFile(data,prodName):
    mprod = data[data.typ==prodName].filter(['API','yrmo','value'],axis=1)
    pivot = mprod.pivot(index='API',columns='yrmo')
    pivot.columns = pivot.columns.get_level_values(1)
    #pivot.head()
    mg = pd.merge(meta,pivot,on='API',how='right',validate='1:1')
    #mg.head()
    mg.to_excel(outdir+'WV_'+prodName+'_production_through_2018.xlsx')

# %%
makeFile(mprod,'GAS')

# %%
makeFile(mprod,'OIL')

# %%
makeFile(mprod,'NGL')
